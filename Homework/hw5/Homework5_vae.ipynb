# %%
# !if [ -d dul_2021 ]; then rm -Rf dul_2021; fi
# !git clone https://github.com/GrigoryBartosh/dul_2021
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1lWjGICwgzgcBDejo9S5g69hLAf0O3lGF' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1lWjGICwgzgcBDejo9S5g69hLAf0O3lGF" -O hw3_data.zip && rm -rf /tmp/cookies.txt
# !unzip -qq hw3_data.zip -d dul_2021/Homework/hw5/data
# !rm hw3_data.zip
# !pip install ./dul_2021
# Out:
# Cloning into 'dul_2021'...
# remote: Enumerating objects: 235, done.
# remote: Counting objects: 100% (235/235), done.
# remote: Compressing objects: 100% (120/120), done.
# remote: Total 235 (delta 107), reused 212 (delta 90), pack-reused 0
# Receiving objects: 100% (235/235), 30.54 MiB | 22.07 MiB/s, done.
# Resolving deltas: 100% (107/107), done.
# --2021-12-02 22:01:17--  https://docs.google.com/uc?export=download&confirm=NuQa&id=1lWjGICwgzgcBDejo9S5g69hLAf0O3lGF
# Resolving docs.google.com (docs.google.com)... 64.233.161.194
# Connecting to docs.google.com (docs.google.com)|64.233.161.194|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0k-b8-docs.googleusercontent.com/docs/securesc/jra5b0sdobvtbrm3lv4lh22b0jhfr1lj/4s30r19th19avu210k8iv9gk0shb2v81/1638471675000/06419056966375271799/02338983424839427398Z/1lWjGICwgzgcBDejo9S5g69hLAf0O3lGF?e=download [following]
# --2021-12-02 22:01:17--  https://doc-0k-b8-docs.googleusercontent.com/docs/securesc/jra5b0sdobvtbrm3lv4lh22b0jhfr1lj/4s30r19th19avu210k8iv9gk0shb2v81/1638471675000/06419056966375271799/02338983424839427398Z/1lWjGICwgzgcBDejo9S5g69hLAf0O3lGF?e=download
# Resolving doc-0k-b8-docs.googleusercontent.com (doc-0k-b8-docs.googleusercontent.com)... 108.177.14.132
# Connecting to doc-0k-b8-docs.googleusercontent.com (doc-0k-b8-docs.googleusercontent.com)|108.177.14.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=u8bbe14mkn2ki&continue=https://doc-0k-b8-docs.googleusercontent.com/docs/securesc/jra5b0sdobvtbrm3lv4lh22b0jhfr1lj/4s30r19th19avu210k8iv9gk0shb2v81/1638471675000/06419056966375271799/02338983424839427398Z/1lWjGICwgzgcBDejo9S5g69hLAf0O3lGF?e%3Ddownload&hash=2boijpu6qe01558bfeaetiqm5frvacjh [following]
# --2021-12-02 22:01:17--  https://docs.google.com/nonceSigner?nonce=u8bbe14mkn2ki&continue=https://doc-0k-b8-docs.googleusercontent.com/docs/securesc/jra5b0sdobvtbrm3lv4lh22b0jhfr1lj/4s30r19th19avu210k8iv9gk0shb2v81/1638471675000/06419056966375271799/02338983424839427398Z/1lWjGICwgzgcBDejo9S5g69hLAf0O3lGF?e%3Ddownload&hash=2boijpu6qe01558bfeaetiqm5frvacjh
# Connecting to docs.google.com (docs.google.com)|64.233.161.194|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-0k-b8-docs.googleusercontent.com/docs/securesc/jra5b0sdobvtbrm3lv4lh22b0jhfr1lj/4s30r19th19avu210k8iv9gk0shb2v81/1638471675000/06419056966375271799/02338983424839427398Z/1lWjGICwgzgcBDejo9S5g69hLAf0O3lGF?e=download&nonce=u8bbe14mkn2ki&user=02338983424839427398Z&hash=nu93btth0ldapgu6afr274l9j5l8mcl1 [following]
# --2021-12-02 22:01:17--  https://doc-0k-b8-docs.googleusercontent.com/docs/securesc/jra5b0sdobvtbrm3lv4lh22b0jhfr1lj/4s30r19th19avu210k8iv9gk0shb2v81/1638471675000/06419056966375271799/02338983424839427398Z/1lWjGICwgzgcBDejo9S5g69hLAf0O3lGF?e=download&nonce=u8bbe14mkn2ki&user=02338983424839427398Z&hash=nu93btth0ldapgu6afr274l9j5l8mcl1
# Connecting to doc-0k-b8-docs.googleusercontent.com (doc-0k-b8-docs.googleusercontent.com)|108.177.14.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 242222000 (231M) [application/zip]
# Saving to: ‘hw3_data.zip’
#
# hw3_data.zip        100%[===================>] 231.00M  23.0MB/s    in 9.6s
#
# 2021-12-02 22:01:28 (24.2 MB/s) - ‘hw3_data.zip’ saved [242222000/242222000]
#
# Processing ./dul_2021
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Building wheels for collected packages: dul-2021
#   Building wheel for dul-2021 (setup.py) ... done
#   Created wheel for dul-2021: filename=dul_2021-0.1.0-py3-none-any.whl size=19088 sha256=1333241e9ecd64130eb3283a2760efd4cf5309b0e7f0ecef73275a3b2ff0f66d
#   Stored in directory: /private/var/folders/zg/dd_4mghs167bb5hrrgz9w4y40000gn/T/pip-ephem-wheel-cache-vynubic0/wheels/8c/b6/de/746b619ea2f759609c8444705a3db15c4d2f3dd8dd4ebc4a07
# Successfully built dul-2021
# Installing collected packages: dul-2021
#   Attempting uninstall: dul-2021
#     Found existing installation: dul-2021 0.1.0
#     Uninstalling dul-2021-0.1.0:
#       Successfully uninstalled dul-2021-0.1.0
# Successfully installed dul-2021-0.1.0

# %%
from dul_2021.utils.hw5_utils import *

import numpy as np
import matplotlib.pyplot as plt
import IPython
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.utils.data as data
from torch.optim import Adam

from tqdm.auto import tqdm

import copy

from scipy.stats import norm
from scipy.optimize import bisect
from tqdm import trange, tqdm_notebook

# %%
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Question 1: VAEs on Images
# In this question, you will train VAE models on image datasets. Execute the cell below to visualize the two datasets (colored shapes, and [SVHN](http://ufldl.stanford.edu/housenumbers/)).

# %%
visualize_svhn()
visualize_cifar10()

# %% [markdown]
# ## Part (a) VAE
# In this part, implement a standard VAE with the following characteristics:
#
# *   16-dim latent variables $z$ with standard normal prior $p(z) = N(0,I)$
# *   An approximate posterior $q_\theta(z|x) = N(z; \mu_\theta(x), \Sigma_\theta(x))$, where $\mu_\theta(x)$ is the mean vector, and $\Sigma_\theta(x)$ is a diagonal covariance matrix
# *   A decoder $p(x|z) = N(x; \mu_\phi(z), I)$, where $\mu_\phi(z)$ is the mean vector. (We are not learning the covariance of the decoder)
#
# You can play around with different architectures and try for better results, but the following encoder / decoder architecture below suffices (Note that image input is always $32\times 32$.
# ```
# conv2d(in_channels, out_channels, kernel_size, stride, padding)
# transpose_conv2d(in_channels, out_channels, kernel_size, stride, padding)
# linear(in_dim, out_dim)
#
# Encoder
#     conv2d(3, 32, 3, 1, 1)
#     relu()
#     conv2d(32, 64, 3, 2, 1) # 16 x 16
#     relu()
#     conv2d(64, 128, 3, 2, 1) # 8 x 8
#     relu()
#     conv2d(128, 256, 3, 2, 1) # 4 x 4
#     relu()
#     flatten()
#     linear(4 * 4 * 256, 2 * latent_dim)
#
# Decoder
#     linear(latent_dim, 4 * 4 * 128)
#     relu()
#     reshape(4, 4, 128)
#     transpose_conv2d(128, 128, 4, 2, 1) # 8 x 8
#     relu()
#     transpose_conv2d(128, 64, 4, 2, 1) # 16 x 16
#     relu()
#     transpose_conv2d(64, 32, 4, 2, 1) # 32 x 32
#     relu()
#     conv2d(32, 3, 3, 1, 1)
# ```
#
# You may find the following training tips helpful
# *   When computing reconstruction loss and KL loss, average over the batch dimension and **sum** over the feature dimension
# *   When computing reconstruction loss, it suffices to just compute MSE between the reconstructed $x$ and true $x$ (you can compute the extra constants if you want)
# *   Use batch size 128, learning rate $10^{-3}$, and an Adam optimizer
#
#
#
#
# **You will provide the following deliverables**
#
#
# 1.   Over the course of training, record the average full negative ELBO, reconstruction loss, and KL term of the training data (per minibatch) and test data (for your entire test set). Code is provided that automatically plots the training curves.
# 2.   Report the final test set performance of your final model
# 3. 100 samples from your trained VAE
# 4. 50 real-image / reconstruction pairs (for some $x$, encode and then decode)
# 5. Interpolations of length 10 between 10 pairs of test images from your VAE (100 images total)

# %%
@torch.no_grad()
def test_epoch(model, dl):
    tloss = trec = tkl = 0.

    for x in tqdm(dl, leave=False, desc='Testing'):
        x = x.to(DEVICE)
        
        x_hat, kl = model(x)
        rec = (x - x_hat).pow(2).sum(x.size()[1:]).mean()
        loss = rec + kl
        
        tloss += loss
        trec += rec
        tkl += kl
        
        n_samples += batch.size(0)

    return [(tloss / len(dl)).item(), (trec / len(dl)).item(), (tkl / len(dl)).item()]


def train_epoch(model, optimizer, dl, loss_acc):
    bar = tqdm(dl, leave=False, desc='Training')
    for x in bar:
        x = x.to(DEVICE)
        
        x_hat, kl = model(x)
        rec = (x - x_hat).pow(2).sum(x.size()[1:]).mean()
        loss = rec + kl
        
        bar.set_postfix_str(f'loss = {loss.item():.5f}')
        loss_acc.append([loss.item(), rec.item(), kl.item()])
        
        optimizer.zero_grad()
        loss.backward()
#         utils.clip_grad_norm_(model.parameters(), 2.)
        optimizer.step()


def train(model, optimizer, train_dl, test_dl, epochs=10):
    train_losses = []
    test_losses = [test_epoch(model, test_dl)]
    
    range_bar = tqdm(range(epochs), desc='Epoch')
    for ep in range_bar:
        train_epoch(model, optimizer, train_dl, train_losses)
        
        loss = test_epoch(model, test_dl)
        test_losses.append(loss)
        range_bar.set_postfix_str(f'test_loss = {loss:.5f}')
        
    return np.array(train_losses), np.array(test_losses)

# %%
class View(nn.Module):
    def __init__(self, *size):
        super().__init__()
        self.size = size
        
    def forward(self, x):
        return x.view(*self.size)
    
    def __repr__(self):
        return f'{self.__class__.__name__}{self.size}'

    
class VAE(nn.Module):
    def __init__(self, img_size, n_layers, latent_size=128, initial_hidden=32, kernel_size=3, mp=2):
        super().__init__()        
        h, w, c = img_size
        
        hs = initial_hidden
        encoder_layers, decoder_layers = (
            [nn.Conv2d(c, hs, kernel_size, 1, kernel_size // 2), nn.ReLU(inplace=True)], 
            [nn.Conv2d(hs, c, kernel_size, 1, kernel_size // 2), nn.ReLU(inplace=True)]
        )
        
        stride = 2
        
        for i in range(n_layers - 1):
            padding = kernel_size // 2
            encoder_layers += [nn.Conv2d(hs, int(hs * mp), kernel_size, stride, padding), nn.ReLU(inplace=True)]
            decoder_layers += [
                nn.ConvTranspose2d(int(hs * mp), hs, kernel_size + 1, stride, padding), nn.ReLU(inplace=True)
            ]
            h, w = (
                int((h + 2 * padding - (kernel_size - 1) - 1) // stride + 1), 
                int((w + 2 * padding - (kernel_size - 1) - 1) // stride + 1)
            )
            hs =  int(hs * mp)
            
        encoder_layers += [View(-1, h * w * hs), nn.Linear(h * w * hs, latent_size * 2)]
        decoder_layers += [View(-1, hs, h, w), nn.Linear(latent_size, h * w * hs)]
        
        self.encoder = nn.Sequential(*encoder_layers)
        self.decoder = nn.Sequential(*decoder_layers[::-1])
        
        self.latent_size = latent_size

        
    def forward(self, x):
        mu, log_var = self.encoder(x).chunk(2, dim=1)
        
        z = self._reparametrize(mu, log_var / 2)
        
        x_hat = self.decoder(z)
        
        kl = (0.5 * (log_var.exp() + mu ** 2 - log_var - 1)).sum(-1).mean()
        
        return x_hat, kl
        
    def _reparametrize(self, mu, log_sigma):
        return mu + torch.randn_like(mu) * log_sigma.exp()
    
    def encode(self, x):
        mu, log_var = self.encoder(x)
        return self._reparametrize(mu, log_var / 2)
    
    def decode(self, z):
        return self.decoder(z)

# %% [markdown]
# ### Solution
# Fill out the function below and return the neccessary arguments. Feel free to create more cells if need be

# %%
def q1_a(train_data, test_data, dset_id):
    """
    train_data: An (n_train, 32, 32, 3) uint8 numpy array of color images with values in {0, ..., 255}
    test_data: An (n_test, 32, 32, 3) uint8 numpy array of color images with values in {0, ..., 255}
    dset_id: An identifying number of which dataset is given (1 or 2). Most likely
               used to set different hyperparameters for different datasets

    Returns
    - a (# of training iterations, 3) numpy array of full negative ELBO, reconstruction loss E[-log p(x|z)],
      and KL term E[KL(q(z|x) | p(z))] evaluated every minibatch
    - a (# of epochs + 1, 3) numpy array of full negative ELBO, reconstruciton loss E[-p(x|z)],
      and KL term E[KL(q(z|x) | p(z))] evaluated once at initialization and after each epoch
    - a (100, 32, 32, 3) numpy array of 100 samples from your VAE with values in {0, ..., 255}
    - a (100, 32, 32, 3) numpy array of 50 real image / reconstruction pairs
      FROM THE TEST SET with values in {0, ..., 255}
    - a (100, 32, 32, 3) numpy array of 10 interpolations of length 10 between
      pairs of test images. The output should be those 100 images flattened into
      the specified shape with values in {0, ..., 255}
    """
    """ YOUR CODE HERE """
    
    img_size = train_data[0].shape
    print(img_size)
    train_data = ((train_data.astype(np.float32) / 255) * 2 - 1).transpose(0, 3, 1, 2)
    test_data = ((train_data.astype(np.float32) / 255) * 2 - 1).transpose(0, 3, 1, 2)
    
    train_dl = data.DataLoader(train_data, batch_size=128, shuffle=True, drop_last=True)
    test_dl = data.DataLoader(test_data, batch_size=128)
    
    vae = VAE(img_size, 4).to(DEVICE)
    optim = Adam(vae.parameters(), lr=1e-3)
    
    train_losses, test_losses = train(vae, optim, train_dl, test_dl)
    
    def to_numpy(imgs):
        imgs = imgs.permute(0, 2, 3, 1).cpu().numpy()
        imgs = 255 * (imgs + 1) / 2
        imgs = imgs.round().astype(np.uint8)
        return imgs
    
    with torch.no_grad():
        samples = to_numpy(vae.decode(torch.randn(100, vae.latent_size, device=DEVICE)))
        
        x = torch.from_numpy(test_data[-50:]).to(DEVICE)
        x_hat, _ = vae(x)
        
        real_rec = to_numpy(torch.cat([x, x_hat], dim=0))
        
        x = torch.from_numpy(test_data[:20]).to(DEVICE)
        z1, z2 = vae(x).chunk(2, dim=0)
        
        interp_points = torch.linspace(0, 1, 10, device=DEVICE)
        zs = (z1[:, None] * ls[:, None] + z2[:, None] * (1 - ls[:, None])).view(100, -1)
        
        interp_imgs = to_numpy(vae(zs))
        
    return train_losses, test_losses, samples, real_rec, interp_imgs

# %% [markdown]
# ### Results
# Once you've finished `q1_a`, execute the cells below to visualize and save your results.

# %%
q1_save_results('a', 1, q1_a)
# Out:
# (32, 32, 3)
# Testing:   0%|          | 0/79 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/zg/dd_4mghs167bb5hrrgz9w4y40000gn/T/ipykernel_16072/2581683782.py in <module>
# ----> 1 q1_save_results('a', 1, q1_a)
#
# ~/PycharmProjects/hse_dul/Homework/hw5/dul_2021/utils/hw5_utils.py in q1_save_results(part, dset_id, fn)
#      56         train_data, test_data = load_pickled_data(join(data_dir, 'cifar10.pkl'))
#      57
# ---> 58     train_losses, test_losses, samples, reconstructions, interpolations = fn(train_data, test_data, dset_id)
#      59     samples, reconstructions, interpolations = samples.astype('float32'), reconstructions.astype(
#      60         'float32'), interpolations.astype('float32')
#
# /var/folders/zg/dd_4mghs167bb5hrrgz9w4y40000gn/T/ipykernel_16072/198313305.py in q1_a(train_data, test_data, dset_id)
#      31     optim = Adam(vae.parameters(), lr=1e-3)
#      32
# ---> 33     train_losses, test_losses = train(vae, optim, train_dl, test_dl)
#      34
#      35     def to_numpy(imgs):
#
# /var/folders/zg/dd_4mghs167bb5hrrgz9w4y40000gn/T/ipykernel_16072/3414365484.py in train(model, optimizer, train_dl, test_dl, epochs)
#      39 def train(model, optimizer, train_dl, test_dl, epochs=10):
#      40     train_losses = []
# ---> 41     test_losses = [test_epoch(model, test_dl)]
#      42
#      43     range_bar = tqdm(range(epochs), desc='Epoch')
#
# ~/.conda/envs/hse_dul/lib/python3.9/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# /var/folders/zg/dd_4mghs167bb5hrrgz9w4y40000gn/T/ipykernel_16072/3414365484.py in test_epoch(model, dl)
#       6         x = x.to(DEVICE)
#       7
# ----> 8         x_hat, kl = model(x)
#       9         rec = (x - x_hat).pow(2).sum(x.size()[1:]).mean()
#      10         loss = rec + kl
#
# ~/.conda/envs/hse_dul/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /var/folders/zg/dd_4mghs167bb5hrrgz9w4y40000gn/T/ipykernel_16072/2754359200.py in forward(self, x)
#      46
#      47     def forward(self, x):
# ---> 48         mu, log_var = self.encoder(x).chunk(2, dim=1)
#      49
#      50         z = self._reparametrize(mu, log_var / 2)
#
# ~/.conda/envs/hse_dul/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.conda/envs/hse_dul/lib/python3.9/site-packages/torch/nn/modules/container.py in forward(self, input)
#     139     def forward(self, input):
#     140         for module in self:
# --> 141             input = module(input)
#     142         return input
#     143
#
# ~/.conda/envs/hse_dul/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/.conda/envs/hse_dul/lib/python3.9/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     444
#     445     def forward(self, input: Tensor) -> Tensor:
# --> 446         return self._conv_forward(input, self.weight, self.bias)
#     447
#     448 class Conv3d(_ConvNd):
#
# ~/.conda/envs/hse_dul/lib/python3.9/site-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     440                             weight, bias, self.stride,
#     441                             _pair(0), self.dilation, self.groups)
# --> 442         return F.conv2d(input, weight, bias, self.stride,
#     443                         self.padding, self.dilation, self.groups)
#     444
#
# RuntimeError: Given groups=1, weight of size [32, 3, 3, 3], expected input[128, 32, 3, 32] to have 3 channels, but got 32 channels instead

# %%
q1_save_results('a', 2, q1_a)
# Out:
# Testing:   0%|          | 0/391 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /var/folders/zg/dd_4mghs167bb5hrrgz9w4y40000gn/T/ipykernel_16072/755004218.py in <module>
# ----> 1 q1_save_results('a', 2, q1_a)
#
# ~/PycharmProjects/hse_dul/Homework/hw5/dul_2021/utils/hw5_utils.py in q1_save_results(part, dset_id, fn)
#      56         train_data, test_data = load_pickled_data(join(data_dir, 'cifar10.pkl'))
#      57
# ---> 58     train_losses, test_losses, samples, reconstructions, interpolations = fn(train_data, test_data, dset_id)
#      59     samples, reconstructions, interpolations = samples.astype('float32'), reconstructions.astype(
#      60         'float32'), interpolations.astype('float32')
#
# /var/folders/zg/dd_4mghs167bb5hrrgz9w4y40000gn/T/ipykernel_16072/1280419096.py in q1_a(train_data, test_data, dset_id)
#      29     optim = Adam(vae.parameters(), lr=1e-3)
#      30
# ---> 31     train_losses, test_losses = train(vae, optim, train_dl, test_dl)
#      32
#      33     def to_numpy(imgs):
#
# /var/folders/zg/dd_4mghs167bb5hrrgz9w4y40000gn/T/ipykernel_16072/4009505542.py in train(model, optimizer, train_dl, test_dl, epochs)
#      39 def train(model, optimizer, train_dl, test_dl, epochs=10):
#      40     train_losses = []
# ---> 41     test_losses = [test_epoch(model, test_dl)]
#      42
#      43     range_bar = tqdm(range(epochs), desc='Epoch')
#
# ~/.conda/envs/hse_dul/lib/python3.9/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# /var/folders/zg/dd_4mghs167bb5hrrgz9w4y40000gn/T/ipykernel_16072/4009505542.py in test_epoch(model, dl)
#       4
#       5     for batch in tqdm(dl, leave=False, desc='Testing'):
# ----> 6         x = x.to(DEVICE)
#       7
#       8         x_hat, kl = model(x)
#
# UnboundLocalError: local variable 'x' referenced before assignment

# %%
q1_save_results('b', 2, q1_b)
